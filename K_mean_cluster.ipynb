# %% [markdown]
# <a href="https://colab.research.google.com/github/Anthony5234534/STAT3011-Project-II/blob/main/K_mean_cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Aim Create a function to do the k mean cluster, input the data frame, out put the the k groups data and then do the visualise

# %% [markdown]
# Reference: ![Screenshot 2025-03-12 at 12.02.38.png](data:image/png;base64,...)

# %%
# S1: Create a data frame with Variable: id, predicted_frequency_in_future_three_month, predicted_monetary_value_in_future_three_month

# %% [markdown]
# Remark: Can first create the data frame by the result of BG/NBD - GG model first, the link is the BG/NBD model result: https://colab.research.google.com/drive/1GCNkGXjxR9XUzz4soiPcU9q71MMFDK9V#scrollTo=3EtZ8usIehqW,
# can use the result to create the data frame first\
# Step1 : How to do the prediction in the file? \
# Step2: How to set the prediction is 3 month \
# Step3: Which variable in the file store the predicted frequency and value?

# %%
# S2: Standardize the variable predicted_frequency_in_future_three_month, predicted_monetary_value_in_future_three_month to prepare the k mean cluster

# %%
# S3: To find the best k

# %%
# S4: To create a function to output the k group

# %%
# S5: Use some graph to visualise  the k group, e.g. scatter plot with k colour, frequency, value as axis, store the most valuable customer id to a variable, and plot the some of them,...)
