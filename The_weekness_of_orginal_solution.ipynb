# %% [markdown]
# <a href="https://colab.research.google.com/github/Anthony5234534/STAT3011-Project-II/blob/main/The_weekness_of_orginal_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# multicollinearity: Check if the featuers are correlated (e.g. present the VIF, corr matrix,... )

# %%
# Stationary : check if the data is stationary (e.g. ADF test? )

# %% [markdown]
# Remark: Which vaiable in orginal solution store the features, how to transfer them into this file?

# %% [markdown]
# orginal solution: https://colab.research.google.com/drive/1SZ2TbIL5sHUcvbviubSEecnVIh4yP_IZ#scrollTo=-_Ijekkp6p6y

# %% [markdown]
# Reference: ![Screenshot 2025-03-12 at 12.01.45.png](data:image/png;base64,...)
