# %% [markdown]
# <a href="https://colab.research.google.com/github/Anthony5234534/STAT3011-Project-II/blob/main/5.%20Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Problem statement and background, approach to the problem in orginal sol, and extension solution (just Brief)

# %%
# Introduction of CLV.

# %% [markdown]
# Refernece ![Screenshot 2025-03-12 at 11.58.40.png](data:image/png;base64,...)

# %% [markdown]
# Reference: \
# Introduction (Choi Chit, Chong Chun Hin)\
# • Problem statement and background \
# •              Importance of Identifying Valuable Customers \
# •              Description of Dataset
#
# Original Analysis (Tang Yu Ching, Ng Yuk)\
# •              Data Preprocessing Steps (Study period 2011-12-09 12:50:00 -
# 2010-12-01 08:26:00)\
# •              (Some) Code Blocks for Original Analysis\
# •              Statistical and Computational Methods Applied (how to train the model) \
# •              Strengths and Limitations of the Analysis
