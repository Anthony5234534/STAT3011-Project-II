# %% [markdown]
# <a href="https://colab.research.google.com/github/Anthony5234534/STAT3011-Project-II/blob/main/Edited_Customer_Lifetime_Value.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Customer Life Time Value

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Uncomment this line if using this notebook locally
#df = pd.read_excel('./data/retail/Online Retail.xlsx', sheet_name='Online Retail')

file_name = "https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/OnlineRetail.xlsx"
df = pd.read_excel(file_name, sheet_name='Online Retail')

df
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %%
# Remove quantities that are less than 0 (possibly returned items)
df = df.loc[df['Quantity'] > 0]

# %%
# Remove blank customer IDs
df = df[pd.notnull(df['CustomerID'])]

# %%
# View our data range
print('Date Range: %s to %s' % (df['InvoiceDate'].min(), df['InvoiceDate'].max()))
# Out:
# Date Range: 2010-12-01 08:26:00 to 2011-12-09 12:50:00

# %%
# taking all of the transactions that occurred before December 01, 2011
df = df.loc[df['InvoiceDate'] < '2011-12-01']

# %%
# Create a Sales Revenue Column
df['Sales'] = df['Quantity'] * df['UnitPrice']

# %%
# Get a orders summary dataset that shows the total in sales made per customer invoice
orders_df = df.groupby(['CustomerID', 'InvoiceNo']).agg({'Sales': sum,'InvoiceDate': max})
# Out:
# <ipython-input-9-609d38e8f42b>:2: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   orders_df = df.groupby(['CustomerID', 'InvoiceNo']).agg({'Sales': sum,'InvoiceDate': max})
# <ipython-input-9-609d38e8f42b>:2: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   orders_df = df.groupby(['CustomerID', 'InvoiceNo']).agg({'Sales': sum,'InvoiceDate': max})

# %%
orders_df.head(10)
# Out:
#                          Sales         InvoiceDate
# CustomerID InvoiceNo
# 12346.0    541431     77183.60 2011-01-18 10:01:00
# 12347.0    537626       711.79 2010-12-07 14:57:00
#            542237       475.39 2011-01-26 14:30:00
#            549222       636.25 2011-04-07 10:43:00
#            556201       382.52 2011-06-09 13:01:00
#            562032       584.91 2011-08-02 08:48:00
#            573511      1294.32 2011-10-31 12:25:00
# 12348.0    539318       892.80 2010-12-16 19:09:00
#            541998       227.44 2011-01-25 10:42:00
#            548955       367.00 2011-04-05 10:47:00

# %%
# Create some simple functions we'll be using to create our summary dataframe

def groupby_mean(x):
    return x.mean()

def groupby_count(x):
    return x.count()

def purchase_duration(x):
    return (x.max() - x.min()).days

def avg_frequency(x):
    '''returns the average days between sales'''
    return (x.max() - x.min()).days/x.count()

groupby_mean.__name__ = 'avg'
groupby_count.__name__ = 'count'
purchase_duration.__name__ = 'purchase_duration'
avg_frequency.__name__ = 'purchase_frequency'

summary_df = orders_df.reset_index().groupby('CustomerID').agg({
    'Sales': [min, max, sum, groupby_mean, groupby_count],
    'InvoiceDate': [min, max, purchase_duration, avg_frequency]
})
# Out:
# <ipython-input-11-b675ee6d9a88>:21: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   summary_df = orders_df.reset_index().groupby('CustomerID').agg({
# <ipython-input-11-b675ee6d9a88>:21: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   summary_df = orders_df.reset_index().groupby('CustomerID').agg({
# <ipython-input-11-b675ee6d9a88>:21: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   summary_df = orders_df.reset_index().groupby('CustomerID').agg({

# %%
summary_df.head(10)
# Out:
#                Sales                                          \
#                  min       max       sum           avg count
# CustomerID
# 12346.0     77183.60  77183.60  77183.60  77183.600000     1
# 12347.0       382.52   1294.32   4085.18    680.863333     6
# 12348.0       227.44    892.80   1797.24    449.310000     4
# 12349.0      1757.55   1757.55   1757.55   1757.550000     1
# 12350.0       334.40    334.40    334.40    334.400000     1
# 12352.0       120.33    840.30   2506.04    313.255000     8
# 12353.0        89.00     89.00     89.00     89.000000     1
# 12354.0      1079.40   1079.40   1079.40   1079.400000     1
# 12355.0       459.40    459.40    459.40    459.400000     1
# 12356.0        58.35   2271.62   2811.43    937.143333     3
#
#                    InvoiceDate                                        \
#                            min                 max purchase_duration
# CustomerID
# 12346.0    2011-01-18 10:01:00 2011-01-18 10:01:00                 0
# 12347.0    2010-12-07 14:57:00 2011-10-31 12:25:00               327
# 12348.0    2010-12-16 19:09:00 2011-09-25 13:13:00               282
# 12349.0    2011-11-21 09:51:00 2011-11-21 09:51:00                 0
# 12350.0    2011-02-02 16:01:00 2011-02-02 16:01:00                 0
# 12352.0    2011-02-16 12:33:00 2011-11-03 14:37:00               260
# 12353.0    2011-05-19 17:47:00 2011-05-19 17:47:00                 0
# 12354.0    2011-04-21 13:11:00 2011-04-21 13:11:00                 0
# 12355.0    2011-05-09 13:49:00 2011-05-09 13:49:00                 0
# 12356.0    2011-01-18 09:50:00 2011-11-17 08:40:00               302
#
#
#            purchase_frequency
# CustomerID
# 12346.0              0.000000
# 12347.0             54.500000
# 12348.0             70.500000
# 12349.0              0.000000
# 12350.0              0.000000
# 12352.0             32.500000
# 12353.0              0.000000
# 12354.0              0.000000
# 12355.0              0.000000
# 12356.0            100.666667

# %%
# Rename our columns by combinng it with the top row
summary_df.columns = ['_'.join(col).lower() for col in summary_df.columns]

# %%
summary_df.head()
# Out:
#             sales_min  sales_max  sales_sum     sales_avg  sales_count  \
# CustomerID
# 12346.0      77183.60   77183.60   77183.60  77183.600000            1
# 12347.0        382.52    1294.32    4085.18    680.863333            6
# 12348.0        227.44     892.80    1797.24    449.310000            4
# 12349.0       1757.55    1757.55    1757.55   1757.550000            1
# 12350.0        334.40     334.40     334.40    334.400000            1
#
#                invoicedate_min     invoicedate_max  \
# CustomerID
# 12346.0    2011-01-18 10:01:00 2011-01-18 10:01:00
# 12347.0    2010-12-07 14:57:00 2011-10-31 12:25:00
# 12348.0    2010-12-16 19:09:00 2011-09-25 13:13:00
# 12349.0    2011-11-21 09:51:00 2011-11-21 09:51:00
# 12350.0    2011-02-02 16:01:00 2011-02-02 16:01:00
#
#             invoicedate_purchase_duration  invoicedate_purchase_frequency
# CustomerID
# 12346.0                                 0                             0.0
# 12347.0                               327                            54.5
# 12348.0                               282                            70.5
# 12349.0                                 0                             0.0
# 12350.0                                 0                             0.0

# %% [markdown]
# ## Visualization

# %%
# Let's look at the first 20 sales counts and the average spend for that sale

# We firstly group by Sales_Counts and then look at the sales_avg
summary_df.groupby('sales_count').count()['sales_avg'][:20]
# Out:
# sales_count
# 1     1539
# 2      806
# 3      515
# 4      381
# 5      228
# 6      172
# 7      132
# 8       97
# 9       60
# 10      45
# 11      54
# 12      47
# 13      29
# 14      19
# 15      24
# 16      13
# 17      15
# 18      11
# 19      15
# 20      10
# Name: sales_avg, dtype: int64

# %%
summary_df = summary_df.loc[summary_df['invoicedate_purchase_duration'] > 0]
summary_df
# Out:
#             sales_min  sales_max  sales_sum    sales_avg  sales_count  \
# CustomerID
# 12347.0        382.52    1294.32    4085.18   680.863333            6
# 12348.0        227.44     892.80    1797.24   449.310000            4
# 12352.0        120.33     840.30    2506.04   313.255000            8
# 12356.0         58.35    2271.62    2811.43   937.143333            3
# 12359.0        547.50    2876.85    6372.58  1593.145000            4
# ...               ...        ...        ...          ...          ...
# 18270.0        111.95     171.20     283.15   141.575000            2
# 18272.0        340.72     753.66    2710.70   542.140000            5
# 18273.0         51.00     102.00     153.00    76.500000            2
# 18283.0          1.95     313.65    1886.88   125.792000           15
# 18287.0         70.68    1001.32    1837.28   612.426667            3
#
#                invoicedate_min     invoicedate_max  \
# CustomerID
# 12347.0    2010-12-07 14:57:00 2011-10-31 12:25:00
# 12348.0    2010-12-16 19:09:00 2011-09-25 13:13:00
# 12352.0    2011-02-16 12:33:00 2011-11-03 14:37:00
# 12356.0    2011-01-18 09:50:00 2011-11-17 08:40:00
# 12359.0    2011-01-12 12:43:00 2011-10-13 12:47:00
# ...                        ...                 ...
# 18270.0    2011-03-18 12:41:00 2011-11-01 13:57:00
# 18272.0    2011-04-07 09:35:00 2011-10-25 11:52:00
# 18273.0    2011-03-27 11:22:00 2011-09-05 11:27:00
# 18283.0    2011-01-06 14:14:00 2011-11-30 12:59:00
# 18287.0    2011-05-22 10:39:00 2011-10-28 09:29:00
#
#             invoicedate_purchase_duration  invoicedate_purchase_frequency
# CustomerID
# 12347.0                               327                       54.500000
# 12348.0                               282                       70.500000
# 12352.0                               260                       32.500000
# 12356.0                               302                      100.666667
# 12359.0                               274                       68.500000
# ...                                   ...                             ...
# 18270.0                               228                      114.000000
# 18272.0                               201                       40.200000
# 18273.0                               162                       81.000000
# 18283.0                               327                       21.800000
# 18287.0                               158                       52.666667
#
# [2692 rows x 9 columns]

# %% [markdown]
# Because we're trying to get the time between sales (plotted in the next cell). We need to eliminate single purchases. That's what this line does.
#
# `summary_df = summary_df.loc[summary_df['invoicedate_purchase_duration'] > 0]`
#
# Purchase durations that are equal to 0 indicate that only purchase was ever made.

# %%
# We filter on invoicedate_purchase_duration greater than 0
summary_df = summary_df.loc[summary_df['invoicedate_purchase_duration'] > 0]

ax = summary_df.groupby('sales_count').count()['sales_avg'][:20].plot(kind='bar', color='skyblue',figsize=(12,7), grid=True)

ax.set_ylabel('count')

plt.show()

# %%
# Now we create a distribution for the average times between sales
ax = summary_df['invoicedate_purchase_frequency'].hist(bins=20, color='skyblue', rwidth=0.7, figsize=(12,7))

ax.set_xlabel('avg. number of days between purchases')
ax.set_ylabel('count')

plt.show()

# %% [markdown]
# # Predicting the 3 month Customer Lifetime Value

# %%
orders_df.head()
# Out:
#                          Sales         InvoiceDate
# CustomerID InvoiceNo
# 12346.0    541431     77183.60 2011-01-18 10:01:00
# 12347.0    537626       711.79 2010-12-07 14:57:00
#            542237       475.39 2011-01-26 14:30:00
#            549222       636.25 2011-04-07 10:43:00
#            556201       382.52 2011-06-09 13:01:00

# %%
# Create summary statistics in 3 month intervals for customer Sales

# Use 3M for 3 month
clv_freq = '3M'

# Groupby customer ID now, and group all invoices for 3 month cycles.
# Aggregate on sum, mean and counts
data_df = orders_df.reset_index().groupby(['CustomerID', pd.Grouper(key='InvoiceDate', freq=clv_freq)]).agg({
    'Sales': [sum, groupby_mean, groupby_count],})

data_df.columns = ['_'.join(col).lower() for col in data_df.columns]
data_df = data_df.reset_index()
data_df.head()
# Out:
# <ipython-input-20-21b01ef552db>:8: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data_df = orders_df.reset_index().groupby(['CustomerID', pd.Grouper(key='InvoiceDate', freq=clv_freq)]).agg({
# <ipython-input-20-21b01ef552db>:8: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   data_df = orders_df.reset_index().groupby(['CustomerID', pd.Grouper(key='InvoiceDate', freq=clv_freq)]).agg({
#    CustomerID InvoiceDate  sales_sum  sales_avg  sales_count
# 0     12346.0  2011-03-31   77183.60  77183.600            1
# 1     12347.0  2010-12-31     711.79    711.790            1
# 2     12347.0  2011-03-31     475.39    475.390            1
# 3     12347.0  2011-06-30    1018.77    509.385            2
# 4     12347.0  2011-09-30     584.91    584.910            1

# %%
# Adding Recency 'M'

# Get the M
date_month_map = {str(x)[:10]: 'M_%s' % (i+1) for i, x in enumerate(sorted(data_df.reset_index()['InvoiceDate'].unique(), reverse=True))}

# Create our M Column
data_df['M'] = data_df['InvoiceDate'].apply(lambda x: date_month_map[str(x)[:10]])
data_df
# Out:
#       CustomerID InvoiceDate  sales_sum     sales_avg  sales_count    M
# 0        12346.0  2011-03-31   77183.60  77183.600000            1  M_4
# 1        12347.0  2010-12-31     711.79    711.790000            1  M_5
# 2        12347.0  2011-03-31     475.39    475.390000            1  M_4
# 3        12347.0  2011-06-30    1018.77    509.385000            2  M_3
# 4        12347.0  2011-09-30     584.91    584.910000            1  M_2
# ...          ...         ...        ...           ...          ...  ...
# 9215     18283.0  2011-06-30     524.68    131.170000            4  M_3
# 9216     18283.0  2011-09-30     278.09     92.696667            3  M_2
# 9217     18283.0  2011-12-31     766.21    153.242000            5  M_1
# 9218     18287.0  2011-06-30     765.28    765.280000            1  M_3
# 9219     18287.0  2011-12-31    1072.00    536.000000            2  M_1
#
# [9220 rows x 6 columns]

# %%
# Added, to calculate the start date and end date

# Assuming you already have the data frame 'data_df' with 'InvoiceDate' column
# First, make sure 'InvoiceDate' is in datetime format
data_df['InvoiceDate'] = pd.to_datetime(data_df['InvoiceDate'])

# Step 1: Find the most recent date (max date) in your dataset
max_date = data_df['InvoiceDate'].max()
print("Most recent date:", max_date)

# Step 2: Calculate the start date of the 3-month period
# Subtract 3 months from the most recent date
start_date_m1 = max_date - pd.DateOffset(months=3)
print("Start date of M1:", start_date_m1)

# Step 3: Define the end date (which is the most recent date itself)
end_date_m1 = max_date
print("End date of M1:", end_date_m1)
# Out:
# Most recent date: 2011-12-31 00:00:00
# Start date of M1: 2011-09-30 00:00:00
# End date of M1: 2011-12-31 00:00:00

# %%
data_df['M'].unique()
# Out:
# array(['M_4', 'M_5', 'M_3', 'M_2', 'M_1'], dtype=object)

# %% [markdown]
# **RFM**
#
# By definition, RFM represents:
#
# - R(ecency): how recently did customer purchase?
# - F(rquency): how often do customer purchase?
# - M(onetary Value): how much do they spend (each time on average)?

# %%
# Create our Features DF
features_df = pd.pivot_table(data_df.loc[data_df['M'] != 'M_1'], values=['sales_sum', 'sales_avg', 'sales_count'], columns='M', index='CustomerID')

features_df.columns = ['_'.join(col) for col in features_df.columns]

features_df.head()
# Out:
#             sales_avg_M_2  sales_avg_M_3  sales_avg_M_4  sales_avg_M_5  \
# CustomerID
# 12346.0               NaN            NaN      77183.600            NaN
# 12347.0            584.91        509.385        475.390         711.79
# 12348.0            310.00        367.000        227.440         892.80
# 12350.0               NaN            NaN        334.400            NaN
# 12352.0            316.25            NaN        312.362            NaN
#
#             sales_count_M_2  sales_count_M_3  sales_count_M_4  \
# CustomerID
# 12346.0                 NaN              NaN              1.0
# 12347.0                 1.0              2.0              1.0
# 12348.0                 1.0              1.0              1.0
# 12350.0                 NaN              NaN              1.0
# 12352.0                 2.0              NaN              5.0
#
#             sales_count_M_5  sales_sum_M_2  sales_sum_M_3  sales_sum_M_4  \
# CustomerID
# 12346.0                 NaN            NaN            NaN       77183.60
# 12347.0                 1.0         584.91        1018.77         475.39
# 12348.0                 1.0         310.00         367.00         227.44
# 12350.0                 NaN            NaN            NaN         334.40
# 12352.0                 NaN         632.50            NaN        1561.81
#
#             sales_sum_M_5
# CustomerID
# 12346.0               NaN
# 12347.0            711.79
# 12348.0            892.80
# 12350.0               NaN
# 12352.0               NaN

# %%
# Create our Response DF
response_df = data_df.loc[data_df['M'] == 'M_1', ['CustomerID', 'sales_sum']]

response_df.columns = ['CustomerID', 'CLV_'+clv_freq]
response_df.head()
# Out:
#     CustomerID   CLV_3M
# 5      12347.0  1294.32
# 10     12349.0  1757.55
# 14     12352.0   311.73
# 20     12356.0    58.35
# 21     12357.0  6207.67

# %%
# Create our Sample Set by merging features with response_df
sample_set_df = features_df.merge(
    response_df,
    left_index=True,
    right_on='CustomerID',
    how='left'
)

sample_set_df = sample_set_df.fillna(0)
sample_set_df.head()
# Out:
#       sales_avg_M_2  sales_avg_M_3  sales_avg_M_4  sales_avg_M_5  \
# NaN            0.00          0.000      77183.600           0.00
# 5.0          584.91        509.385        475.390         711.79
# NaN          310.00        367.000        227.440         892.80
# NaN            0.00          0.000        334.400           0.00
# 14.0         316.25          0.000        312.362           0.00
#
#       sales_count_M_2  sales_count_M_3  sales_count_M_4  sales_count_M_5  \
# NaN               0.0              0.0              1.0              0.0
# 5.0               1.0              2.0              1.0              1.0
# NaN               1.0              1.0              1.0              1.0
# NaN               0.0              0.0              1.0              0.0
# 14.0              2.0              0.0              5.0              0.0
#
#       sales_sum_M_2  sales_sum_M_3  sales_sum_M_4  sales_sum_M_5  CustomerID  \
# NaN            0.00           0.00       77183.60           0.00     12346.0
# 5.0          584.91        1018.77         475.39         711.79     12347.0
# NaN          310.00         367.00         227.44         892.80     12348.0
# NaN            0.00           0.00         334.40           0.00     12350.0
# 14.0         632.50           0.00        1561.81           0.00     12352.0
#
#        CLV_3M
# NaN      0.00
# 5.0   1294.32
# NaN      0.00
# NaN      0.00
# 14.0   311.73

# %% [markdown]
# # Using Linear Regression

# %%
# Linear regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Our Target Variable
target_var = 'CLV_'+clv_freq

# Our Features
all_features = [x for x in sample_set_df.columns if x not in ['CustomerID', target_var]]

#Set seed
seed_value = 3011

# Split data in Train and Test
x_train, x_test, y_train, y_test = train_test_split(sample_set_df[all_features], sample_set_df[target_var], test_size=0.3)

# Fit Model
reg_fit = LinearRegression()
reg_fit.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Get our y intercept
reg_fit.intercept_
# Out:
# 25.88676132222895

# %%
# Get our coefficents
reg_fit.coef_
# Out:
# array([-3.19982411e-01,  6.14919786e-02,  2.44422915e-01, -4.60606622e-01,
#         4.68393291e+01, -4.25999884e+01, -2.71101266e+01,  5.42692459e+01,
#         4.60444562e-01,  3.68344397e-01,  1.74916186e-02,  4.81499609e-01])

# %%
# Show them here per feature
coef = pd.DataFrame(list(zip(all_features, reg_fit.coef_)))
coef.columns = ['feature', 'coef']

coef
# Out:
#             feature       coef
# 0     sales_avg_M_2  -0.319982
# 1     sales_avg_M_3   0.061492
# 2     sales_avg_M_4   0.244423
# 3     sales_avg_M_5  -0.460607
# 4   sales_count_M_2  46.839329
# 5   sales_count_M_3 -42.599988
# 6   sales_count_M_4 -27.110127
# 7   sales_count_M_5  54.269246
# 8     sales_sum_M_2   0.460445
# 9     sales_sum_M_3   0.368344
# 10    sales_sum_M_4   0.017492
# 11    sales_sum_M_5   0.481500

# %%
# Run our input data into our model predictors
train_preds = reg_fit.predict(x_train)
test_preds = reg_fit.predict(x_test)

# %%
# Assess performance Training Data
from sklearn.metrics import r2_score, median_absolute_error

print(r2_score(y_true=y_train, y_pred=train_preds))
print(median_absolute_error(y_true=y_train, y_pred=train_preds))
# Out:
# 0.8446800659602808
# 168.05318145983262

# %%
# Compare R-Squared Performance on Training and Test Datasets
print('In-Sample R-Squared: %0.4f' % r2_score(y_true = y_train, y_pred = train_preds))
print('Out-of-Sample R-Squared: %0.4f' % r2_score(y_true = y_test, y_pred = test_preds))
# Out:
# In-Sample R-Squared: 0.8447
# Out-of-Sample R-Squared: 0.5058

# %%
# Compare MSE on Training and Test Datasets
print('In-Sample MSE: %0.4f' % median_absolute_error(y_true = y_train, y_pred = train_preds))
print('Out-of-Sample MSE: %0.4f' % median_absolute_error(y_true = y_test, y_pred = test_preds))
# Out:
# In-Sample MSE: 168.0532
# Out-of-Sample MSE: 162.0528

# %%
# Plot the predicted vs actual values using our Test Dataset
plt.scatter(y_test, test_preds)
plt.plot([0, max(y_test)], [0, max(test_preds)], color='gray', lw=1, linestyle='--')

plt.xlabel('actual')
plt.ylabel('predicted')
plt.title('Out-of-Sample Actual vs. Predicted')
plt.grid()

plt.show()

# %%
sum_diff = (abs(y_test - test_preds)).sum()
print(f"Sum of Differences (Actual - Predicted): {sum_diff:.2f}")
# Out:
# Sum of Differences (Actual - Predicted): 549352.25

# %%
sum(y_test - test_preds)
# Out:
# -40471.68229366713

# %%
len(y_test)
# Out:
# 1085

# %%
df = pd.DataFrame({
    'Actual': y_test,
    'Predicted': test_preds,
    'difference': abs(y_test - test_preds)
})

# Display the DataFrame
df
# Out:
#         Actual   Predicted  difference
# NaN       0.00  129.006606  129.006606
# 9043.0  237.00  244.105311    7.105311
# 7531.0  659.14  234.613472  424.526528
# NaN       0.00   87.402198   87.402198
# NaN       0.00   87.469806   87.469806
# ...        ...         ...         ...
# 7618.0  879.95  634.277784  245.672216
# 1026.0  972.27  170.302736  801.967264
# NaN       0.00  149.927633  149.927633
# NaN       0.00  244.565519  244.565519
# 5357.0  168.12  103.201791   64.918209
#
# [1085 rows x 3 columns]
